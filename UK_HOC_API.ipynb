# %% [markdown]
# # UK House of Commons API
#
# - [https://developer.parliament.uk/](https://developer.parliament.uk/)
#
#
# ## Task
#
# Suppose we want to understand the types of questions that are being asked during Prime Minister's Questions (PMQs) in the UK House of Commons. We can use the UK House of Commons API to retrieve data about PMQs and analyze the types of questions being asked.
#
# We will use the UK House of Commons API to retrieve data on PMQs. We will first learn how the API works, examining the output format and the available endpoints. Then, we will write a Python script to retrieve data on PMQs in 2025. Once we have the data, we will create a `pandas` DataFrame that contains a single row for each observation, with columns for the question text, the date it was asked, and the name of the MP who asked it.
#
# **Note:** Whenever we start collecting data from an API, we want to think about how we can use the data to answer a specific question. This often means that we should have in mind the type of analysis we want to perform, which will help us structure our data collection and analysis process.

# %%
pip install pandas requests
# Out:
# Requirement already satisfied: pandas in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: requests in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from pandas) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /home/zach/anaconda3/envs/my580_APIs/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import requests

# %% [markdown]
# # Step 1: Understand the API
#
# - We need to identify the endpoints that provide data on PMQs. The url for the API documentation is [https://developer.parliament.uk/](https://developer.parliament.uk/).
# - Once we have identified the endpoints, we can use tools like `curl` or `Postman` to test the API and understand the output format.
# - The Endpoint for PMQs is `oralquestions`, which provides data on oral questions asked in the House of Commons.
#
#
# The full URL for the PMQs endpoint is:
# ```
# https://oralquestionsandmotions-api.parliament.uk/oralquestions/list
# ```

# %%
PMQs_endpoint = "https://oralquestionsandmotions-api.parliament.uk/oralquestions/list"

# %% [markdown]
# ### We would usually like to write a function to get the data, but for simplicity, let's work through the collection process step by step

# %%
# send a GET request to the endpoint
r = requests.get(PMQs_endpoint)

# check if the request was successful
print(f"Status code: {r.status_code}")
# Out:
# Status code: 200

# %%
# let's convert the response to JSON
data = r.json()

# %%
# let's inspect the data
data
# Out:
# {'PagingInfo': {'Skip': 0,
#   'Take': 40,
#   'Total': 37601,
#   'GlobalTotal': 37601,
#   'StatusCounts': [],
#   'GlobalStatusCounts': []},
#  'StatusCode': 200,
#  'Success': True,
#  'Errors': [],
#  'Response': [{'Id': 1207,
#    'QuestionType': 1,
#    'QuestionText': 'What recent steps she has taken to reduce the level of knife crime.',
#    'Status': 5,
#    'Number': 1,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901905,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4498,
#     'PimsId': 6091,
#     'Name': 'Mr Ranil Jayawardena',
#     'ListAs': 'Jayawardena, Mr Ranil',
#     'Constituency': 'North East Hampshire',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4498/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4498,
#    'AnsweringMinisterId': 0},
#   {'Id': 1232,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 1,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901895,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4664,
#     'PimsId': 6239,
#     'Name': 'Ms Karen Lee',
#     'ListAs': 'Lee, Ms Karen',
#     'Constituency': 'Lincoln',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4664/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4664,
#    'AnsweringMinisterId': 0},
#   {'Id': 1208,
#    'QuestionType': 1,
#    'QuestionText': 'What steps she is taking to reduce dangerous journeys for unaccompanied child refugees with family in the UK.',
#    'Status': 5,
#    'Number': 2,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901906,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4598,
#     'PimsId': 6219,
#     'Name': 'Mohammad Yasin',
#     'ListAs': 'Yasin, Mohammad',
#     'Constituency': 'Bedford',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4598/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4598,
#    'AnsweringMinisterId': 0},
#   {'Id': 1233,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 7,
#    'Number': 2,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': '2017-11-17T12:47:47.527',
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901896,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4453,
#     'PimsId': 6152,
#     'Name': 'Tommy Sheppard',
#     'ListAs': 'Sheppard, Tommy',
#     'Constituency': 'Edinburgh East',
#     'Status': 'Active',
#     'Party': 'Scottish National Party',
#     'PartyId': 29,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4453/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4453,
#    'AnsweringMinisterId': 0},
#   {'Id': 1209,
#    'QuestionType': 1,
#    'QuestionText': 'What steps she is taking to reduce dangerous journeys for unaccompanied child refugees with family in the UK.',
#    'Status': 5,
#    'Number': 3,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901907,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 481,
#     'PimsId': 1031,
#     'Name': 'Mr George Howarth',
#     'ListAs': 'Howarth, Mr George',
#     'Constituency': 'Knowsley',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/481/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 481,
#    'AnsweringMinisterId': 0},
#   {'Id': 1234,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 3,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901897,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4127,
#     'PimsId': 5708,
#     'Name': 'Julie Elliott',
#     'ListAs': 'Elliott, Julie',
#     'Constituency': 'Sunderland Central',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4127/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4127,
#    'AnsweringMinisterId': 0},
#   {'Id': 1210,
#    'QuestionType': 1,
#    'QuestionText': 'How many applications for indefinite leave to remain are under consideration by her Department.',
#    'Status': 5,
#    'Number': 4,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901908,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 318,
#     'PimsId': 781,
#     'Name': 'John Spellar',
#     'ListAs': 'Spellar, John',
#     'Constituency': 'Warley',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/318/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 318,
#    'AnsweringMinisterId': 0},
#   {'Id': 1235,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 4,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901898,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4631,
#     'PimsId': 6231,
#     'Name': 'Sarah Jones',
#     'ListAs': 'Jones, Sarah',
#     'Constituency': 'Croydon Central',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4631/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4631,
#    'AnsweringMinisterId': 0},
#   {'Id': 1211,
#    'QuestionType': 1,
#    'QuestionText': 'What discussions she has had with Cabinet colleagues on the economic effect of changes to immigration rules after the UK leaves the EU.',
#    'Status': 5,
#    'Number': 5,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901909,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4619,
#     'PimsId': 6228,
#     'Name': 'Mr Alister Jack',
#     'ListAs': 'Jack, Mr Alister',
#     'Constituency': 'Dumfries and Galloway',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4619/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4619,
#    'AnsweringMinisterId': 0},
#   {'Id': 1236,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 5,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901899,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4598,
#     'PimsId': 6219,
#     'Name': 'Mohammad Yasin',
#     'ListAs': 'Yasin, Mohammad',
#     'Constituency': 'Bedford',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4598/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4598,
#    'AnsweringMinisterId': 0},
#   {'Id': 1212,
#    'QuestionType': 1,
#    'QuestionText': 'What discussions she has had with the Chancellor of the Exchequer on additional funding to increase the remuneration of people employed by fire and rescue services.',
#    'Status': 5,
#    'Number': 6,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901910,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4638,
#     'PimsId': 6209,
#     'Name': 'Mr Tanmanjeet Singh Dhesi',
#     'ListAs': 'Dhesi, Mr Tanmanjeet Singh',
#     'Constituency': 'Slough',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4638/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4638,
#    'AnsweringMinisterId': 0},
#   {'Id': 1237,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 6,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901900,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4517,
#     'PimsId': 6065,
#     'Name': 'Lucy Frazer',
#     'ListAs': 'Frazer, Lucy',
#     'Constituency': 'South East Cambridgeshire',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4517/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4517,
#    'AnsweringMinisterId': 0},
#   {'Id': 1213,
#    'QuestionType': 1,
#    'QuestionText': 'Whether her Department has commissioned research into alternatives to the use of immigration detention centres.',
#    'Status': 5,
#    'Number': 7,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901911,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 188,
#     'PimsId': 2851,
#     'Name': 'Sir Edward Davey',
#     'ListAs': 'Davey, Sir Edward',
#     'Constituency': 'Kingston and Surbiton',
#     'Status': 'Active',
#     'Party': 'Liberal Democrat',
#     'PartyId': 17,
#     'PartyColour': 'faa01a',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/188/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 188,
#    'AnsweringMinisterId': 0},
#   {'Id': 1238,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 7,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901901,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4640,
#     'PimsId': 6241,
#     'Name': 'David Linden',
#     'ListAs': 'Linden, David',
#     'Constituency': 'Glasgow East',
#     'Status': 'Active',
#     'Party': 'Scottish National Party',
#     'PartyId': 29,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4640/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4640,
#    'AnsweringMinisterId': 0},
#   {'Id': 1214,
#    'QuestionType': 1,
#    'QuestionText': 'What assessment she has made of the effectiveness of regional organised crime units.',
#    'Status': 5,
#    'Number': 8,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901912,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4517,
#     'PimsId': 6065,
#     'Name': 'Lucy Frazer',
#     'ListAs': 'Frazer, Lucy',
#     'Constituency': 'South East Cambridgeshire',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4517/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4517,
#    'AnsweringMinisterId': 0},
#   {'Id': 1239,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 8,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901902,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4369,
#     'PimsId': 6140,
#     'Name': 'Tom Pursglove',
#     'ListAs': 'Pursglove, Tom',
#     'Constituency': 'Corby',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4369/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4369,
#    'AnsweringMinisterId': 0},
#   {'Id': 1215,
#    'QuestionType': 1,
#    'QuestionText': 'If she will meet representatives from the Scottish fishing industry to discuss visas for crew members from outside the EEA.',
#    'Status': 5,
#    'Number': 9,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901913,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 1442,
#     'PimsId': 2481,
#     'Name': 'Mr Alistair Carmichael',
#     'ListAs': 'Carmichael, Mr Alistair',
#     'Constituency': 'Orkney and Shetland',
#     'Status': 'Active',
#     'Party': 'Liberal Democrat',
#     'PartyId': 17,
#     'PartyColour': 'faa01a',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1442/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 1442,
#    'AnsweringMinisterId': 0},
#   {'Id': 1240,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 9,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901903,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4267,
#     'PimsId': 6005,
#     'Name': 'Sarah Champion',
#     'ListAs': 'Champion, Sarah',
#     'Constituency': 'Rotherham',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4267/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4267,
#    'AnsweringMinisterId': 0},
#   {'Id': 1216,
#    'QuestionType': 1,
#    'QuestionText': 'What progress she has made on bringing perpetrators of major cyber crimes to justice.',
#    'Status': 5,
#    'Number': 10,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901914,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4669,
#     'PimsId': 6248,
#     'Name': 'Damien Moore',
#     'ListAs': 'Moore, Damien',
#     'Constituency': 'Southport',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4669/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4669,
#    'AnsweringMinisterId': 0},
#   {'Id': 1241,
#    'QuestionType': 2,
#    'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#    'Status': 5,
#    'Number': 10,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901904,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 308,
#     'PimsId': 2803,
#     'Name': 'Mr Jim Cunningham',
#     'ListAs': 'Cunningham, Mr Jim',
#     'Constituency': 'Coventry South',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/308/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 308,
#    'AnsweringMinisterId': 0},
#   {'Id': 1217,
#    'QuestionType': 1,
#    'QuestionText': "Whether she plans to exclude international students from the Government's net migration target.",
#    'Status': 5,
#    'Number': 11,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901915,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 1604,
#     'PimsId': 5258,
#     'Name': 'Mr Virendra Sharma',
#     'ListAs': 'Sharma, Mr Virendra',
#     'Constituency': 'Ealing, Southall',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1604/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 1604,
#    'AnsweringMinisterId': 0},
#   {'Id': 1218,
#    'QuestionType': 1,
#    'QuestionText': 'What progress she has made on implementing the Dubs scheme.',
#    'Status': 5,
#    'Number': 12,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901916,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4634,
#     'PimsId': 6229,
#     'Name': 'Christine Jardine',
#     'ListAs': 'Jardine, Christine',
#     'Constituency': 'Edinburgh West',
#     'Status': 'Active',
#     'Party': 'Liberal Democrat',
#     'PartyId': 17,
#     'PartyColour': 'faa01a',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4634/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4634,
#    'AnsweringMinisterId': 0},
#   {'Id': 1219,
#    'QuestionType': 1,
#    'QuestionText': 'What recent steps she has taken to reduce the level of knife crime.',
#    'Status': 5,
#    'Number': 13,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901917,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 1585,
#     'PimsId': 4786,
#     'Name': 'Stephen Hammond',
#     'ListAs': 'Hammond, Stephen',
#     'Constituency': 'Wimbledon',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1585/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 1585,
#    'AnsweringMinisterId': 0},
#   {'Id': 1220,
#    'QuestionType': 1,
#    'QuestionText': 'Whether she plans to introduce a new police funding formula in the next 12 months.',
#    'Status': 5,
#    'Number': 14,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901918,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4136,
#     'PimsId': 5712,
#     'Name': 'Nigel Mills',
#     'ListAs': 'Mills, Nigel',
#     'Constituency': 'Amber Valley',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4136/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4136,
#    'AnsweringMinisterId': 0},
#   {'Id': 1221,
#    'QuestionType': 1,
#    'QuestionText': 'What representations she has received from higher education organisations on the Tier 4 visa pilot scheme for Masters students.',
#    'Status': 5,
#    'Number': 15,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901919,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4604,
#     'PimsId': 6233,
#     'Name': 'Stephen Kerr',
#     'ListAs': 'Kerr, Stephen',
#     'Constituency': 'Stirling',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4604/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4604,
#    'AnsweringMinisterId': 0},
#   {'Id': 1222,
#    'QuestionType': 1,
#    'QuestionText': 'What steps she is taking to identify, and prosecute people who return to the UK from fighting for Daesh in Syria.',
#    'Status': 11,
#    'Number': 16,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': '2017-11-20T16:23:30.48',
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901920,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4429,
#     'PimsId': 6058,
#     'Name': 'Mr William Wragg',
#     'ListAs': 'Wragg, Mr William',
#     'Constituency': 'Hazel Grove',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4429/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4429,
#    'AnsweringMinisterId': 0},
#   {'Id': 1223,
#    'QuestionType': 1,
#    'QuestionText': 'Whether her Department plans to review the effectiveness of its policy on indefinite detention. ',
#    'Status': 5,
#    'Number': 17,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901921,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4651,
#     'PimsId': 6204,
#     'Name': 'Dan Carden',
#     'ListAs': 'Carden, Dan',
#     'Constituency': 'Liverpool, Walton',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4651/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4651,
#    'AnsweringMinisterId': 0},
#   {'Id': 1224,
#    'QuestionType': 1,
#    'QuestionText': 'What discussions she has had with the Chancellor of the Exchequer on additional fundng to increase the remuneration of (a) police officers and (b) fire and rescue service workers; and if she will make a statement.',
#    'Status': 5,
#    'Number': 18,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901922,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4645,
#     'PimsId': 6223,
#     'Name': 'Emma Hardy',
#     'ListAs': 'Hardy, Emma',
#     'Constituency': 'Kingston upon Hull West and Hessle',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4645/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4645,
#    'AnsweringMinisterId': 0},
#   {'Id': 1225,
#    'QuestionType': 1,
#    'QuestionText': 'What steps she is taking to reduce dangerous journeys for unaccompanied child refugees with family in the UK.',
#    'Status': 5,
#    'Number': 19,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901923,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4469,
#     'PimsId': 6043,
#     'Name': 'Angela Crawley',
#     'ListAs': 'Crawley, Angela',
#     'Constituency': 'Lanark and Hamilton East',
#     'Status': 'Active',
#     'Party': 'Scottish National Party',
#     'PartyId': 29,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4469/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4469,
#    'AnsweringMinisterId': 0},
#   {'Id': 1226,
#    'QuestionType': 1,
#    'QuestionText': 'What discussions she has had with Cabinet colleagues on the effect of recent cyber-attacks on critical national infrastructure.',
#    'Status': 11,
#    'Number': 20,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': '2017-11-20T16:24:18.167',
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901924,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4501,
#     'PimsId': 6093,
#     'Name': 'Gerald Jones',
#     'ListAs': 'Jones, Gerald',
#     'Constituency': 'Merthyr Tydfil and Rhymney',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4501/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4501,
#    'AnsweringMinisterId': 0},
#   {'Id': 1227,
#    'QuestionType': 1,
#    'QuestionText': 'What steps she is taking to ensure that businesses have access to temporary non-UK EU workers after the UK leaves the EU.',
#    'Status': 11,
#    'Number': 21,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': '2017-11-20T16:24:42.857',
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901925,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4050,
#     'PimsId': 5579,
#     'Name': 'Gordon Henderson',
#     'ListAs': 'Henderson, Gordon',
#     'Constituency': 'Sittingbourne and Sheppey',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4050/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4050,
#    'AnsweringMinisterId': 0},
#   {'Id': 1228,
#    'QuestionType': 1,
#    'QuestionText': 'Whether her Department plans to review the effectiveness of the Prevent strategy.',
#    'Status': 11,
#    'Number': 22,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': '2017-11-20T16:24:57.787',
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901926,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4588,
#     'PimsId': 6190,
#     'Name': 'Tracy Brabin',
#     'ListAs': 'Brabin, Tracy',
#     'Constituency': 'Batley and Spen',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4588/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4588,
#    'AnsweringMinisterId': 0},
#   {'Id': 1229,
#    'QuestionType': 1,
#    'QuestionText': "Whether she plans to exclude international students from the Government's net migration target.",
#    'Status': 5,
#    'Number': 23,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901927,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4425,
#     'PimsId': 6163,
#     'Name': 'Jo Stevens',
#     'ListAs': 'Stevens, Jo',
#     'Constituency': 'Cardiff Central',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4425/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4425,
#    'AnsweringMinisterId': 0},
#   {'Id': 1230,
#    'QuestionType': 1,
#    'QuestionText': 'What progress the Government has made on placing vulnerable Syrian refugee families in the UK.',
#    'Status': 11,
#    'Number': 24,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': '2017-11-20T16:25:10.14',
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901928,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 4401,
#     'PimsId': 6139,
#     'Name': 'Victoria Prentis',
#     'ListAs': 'Prentis, Victoria',
#     'Constituency': 'Banbury',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4401/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4401,
#    'AnsweringMinisterId': 0},
#   {'Id': 1231,
#    'QuestionType': 1,
#    'QuestionText': "Whether she plans to exclude international students from the Government's net migration target",
#    'Status': 5,
#    'Number': 25,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901929,
#    'AnsweringWhen': '2017-11-20T00:00:00',
#    'AnsweringBodyId': 1,
#    'AnsweringBody': 'Home Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#    'AskingMember': {'MnisId': 308,
#     'PimsId': 2803,
#     'Name': 'Mr Jim Cunningham',
#     'ListAs': 'Cunningham, Mr Jim',
#     'Constituency': 'Coventry South',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/308/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 308,
#    'AnsweringMinisterId': 0},
#   {'Id': 1334,
#    'QuestionType': 1,
#    'QuestionText': 'When he last spoke with a representative of the Government of the Russian Federation.',
#    'Status': 5,
#    'Number': 1,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901940,
#    'AnsweringWhen': '2017-11-21T00:00:00',
#    'AnsweringBodyId': 16,
#    'AnsweringBody': 'Foreign and Commonwealth Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#    'AskingMember': {'MnisId': 1446,
#     'PimsId': 2350,
#     'Name': 'Chris Bryant',
#     'ListAs': 'Bryant, Chris',
#     'Constituency': 'Rhondda',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1446/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 1446,
#    'AnsweringMinisterId': 0},
#   {'Id': 1359,
#    'QuestionType': 2,
#    'QuestionText': 'If he will make a statement on his departmental responsibilities.',
#    'Status': 5,
#    'Number': 1,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901930,
#    'AnsweringWhen': '2017-11-21T00:00:00',
#    'AnsweringBodyId': 16,
#    'AnsweringBody': 'Foreign and Commonwealth Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#    'AskingMember': {'MnisId': 1533,
#     'PimsId': 4791,
#     'Name': 'Diana Johnson',
#     'ListAs': 'Johnson, Diana',
#     'Constituency': 'Kingston upon Hull North',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1533/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 1533,
#    'AnsweringMinisterId': 0},
#   {'Id': 1335,
#    'QuestionType': 1,
#    'QuestionText': 'What progress he has made on preparations for the Commonwealth Summit in London in April 2018.',
#    'Status': 5,
#    'Number': 2,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901941,
#    'AnsweringWhen': '2017-11-21T00:00:00',
#    'AnsweringBodyId': 16,
#    'AnsweringBody': 'Foreign and Commonwealth Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#    'AskingMember': {'MnisId': 4532,
#     'PimsId': 6167,
#     'Name': 'Derek Thomas',
#     'ListAs': 'Thomas, Derek',
#     'Constituency': 'St Ives',
#     'Status': 'Active',
#     'Party': 'Conservative',
#     'PartyId': 4,
#     'PartyColour': None,
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4532/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4532,
#    'AnsweringMinisterId': 0},
#   {'Id': 1360,
#    'QuestionType': 2,
#    'QuestionText': 'If he will make a statement on his departmental responsibilities.',
#    'Status': 5,
#    'Number': 2,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901931,
#    'AnsweringWhen': '2017-11-21T00:00:00',
#    'AnsweringBodyId': 16,
#    'AnsweringBody': 'Foreign and Commonwealth Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#    'AskingMember': {'MnisId': 4382,
#     'PimsId': 6025,
#     'Name': 'Daniel Zeichner',
#     'ListAs': 'Zeichner, Daniel',
#     'Constituency': 'Cambridge',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4382/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 4382,
#    'AnsweringMinisterId': 0},
#   {'Id': 1336,
#    'QuestionType': 1,
#    'QuestionText': 'What recent representations he has made to his counterpart in Myanmar on the treatment of the Rohingya people in that country.',
#    'Status': 5,
#    'Number': 3,
#    'TabledWhen': '2017-11-17T00:00:00',
#    'RemovedFromToBeAskedWhen': None,
#    'DeclarableInterestDetail': None,
#    'HansardLink': '',
#    'UIN': 901942,
#    'AnsweringWhen': '2017-11-21T00:00:00',
#    'AnsweringBodyId': 16,
#    'AnsweringBody': 'Foreign and Commonwealth Office',
#    'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#    'AskingMember': {'MnisId': 1548,
#     'PimsId': 4824,
#     'Name': 'Jessica Morden',
#     'ListAs': 'Morden, Jessica',
#     'Constituency': 'Newport East',
#     'Status': 'Active',
#     'Party': 'Labour',
#     'PartyId': 15,
#     'PartyColour': 'd50000',
#     'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1548/Portrait?cropType=OneOne&webVersion=true'},
#    'AnsweringMinister': None,
#    'AskingMemberId': 1548,
#    'AnsweringMinisterId': 0}]}

# %%
# we can call the 'PagingInfo' key to get information about the pagination
data['PagingInfo']
# Out:
# {'Skip': 0,
#  'Take': 40,
#  'Total': 37601,
#  'GlobalTotal': 37601,
#  'StatusCounts': [],
#  'GlobalStatusCounts': []}

# %%
# to get the response data, we can access the 'Response' key
data['Response']
# Out:
# [{'Id': 1207,
#   'QuestionType': 1,
#   'QuestionText': 'What recent steps she has taken to reduce the level of knife crime.',
#   'Status': 5,
#   'Number': 1,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901905,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4498,
#    'PimsId': 6091,
#    'Name': 'Mr Ranil Jayawardena',
#    'ListAs': 'Jayawardena, Mr Ranil',
#    'Constituency': 'North East Hampshire',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4498/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4498,
#   'AnsweringMinisterId': 0},
#  {'Id': 1232,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 1,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901895,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4664,
#    'PimsId': 6239,
#    'Name': 'Ms Karen Lee',
#    'ListAs': 'Lee, Ms Karen',
#    'Constituency': 'Lincoln',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4664/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4664,
#   'AnsweringMinisterId': 0},
#  {'Id': 1208,
#   'QuestionType': 1,
#   'QuestionText': 'What steps she is taking to reduce dangerous journeys for unaccompanied child refugees with family in the UK.',
#   'Status': 5,
#   'Number': 2,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901906,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4598,
#    'PimsId': 6219,
#    'Name': 'Mohammad Yasin',
#    'ListAs': 'Yasin, Mohammad',
#    'Constituency': 'Bedford',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4598/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4598,
#   'AnsweringMinisterId': 0},
#  {'Id': 1233,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 7,
#   'Number': 2,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': '2017-11-17T12:47:47.527',
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901896,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4453,
#    'PimsId': 6152,
#    'Name': 'Tommy Sheppard',
#    'ListAs': 'Sheppard, Tommy',
#    'Constituency': 'Edinburgh East',
#    'Status': 'Active',
#    'Party': 'Scottish National Party',
#    'PartyId': 29,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4453/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4453,
#   'AnsweringMinisterId': 0},
#  {'Id': 1209,
#   'QuestionType': 1,
#   'QuestionText': 'What steps she is taking to reduce dangerous journeys for unaccompanied child refugees with family in the UK.',
#   'Status': 5,
#   'Number': 3,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901907,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 481,
#    'PimsId': 1031,
#    'Name': 'Mr George Howarth',
#    'ListAs': 'Howarth, Mr George',
#    'Constituency': 'Knowsley',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/481/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 481,
#   'AnsweringMinisterId': 0},
#  {'Id': 1234,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 3,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901897,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4127,
#    'PimsId': 5708,
#    'Name': 'Julie Elliott',
#    'ListAs': 'Elliott, Julie',
#    'Constituency': 'Sunderland Central',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4127/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4127,
#   'AnsweringMinisterId': 0},
#  {'Id': 1210,
#   'QuestionType': 1,
#   'QuestionText': 'How many applications for indefinite leave to remain are under consideration by her Department.',
#   'Status': 5,
#   'Number': 4,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901908,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 318,
#    'PimsId': 781,
#    'Name': 'John Spellar',
#    'ListAs': 'Spellar, John',
#    'Constituency': 'Warley',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/318/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 318,
#   'AnsweringMinisterId': 0},
#  {'Id': 1235,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 4,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901898,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4631,
#    'PimsId': 6231,
#    'Name': 'Sarah Jones',
#    'ListAs': 'Jones, Sarah',
#    'Constituency': 'Croydon Central',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4631/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4631,
#   'AnsweringMinisterId': 0},
#  {'Id': 1211,
#   'QuestionType': 1,
#   'QuestionText': 'What discussions she has had with Cabinet colleagues on the economic effect of changes to immigration rules after the UK leaves the EU.',
#   'Status': 5,
#   'Number': 5,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901909,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4619,
#    'PimsId': 6228,
#    'Name': 'Mr Alister Jack',
#    'ListAs': 'Jack, Mr Alister',
#    'Constituency': 'Dumfries and Galloway',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4619/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4619,
#   'AnsweringMinisterId': 0},
#  {'Id': 1236,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 5,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901899,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4598,
#    'PimsId': 6219,
#    'Name': 'Mohammad Yasin',
#    'ListAs': 'Yasin, Mohammad',
#    'Constituency': 'Bedford',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4598/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4598,
#   'AnsweringMinisterId': 0},
#  {'Id': 1212,
#   'QuestionType': 1,
#   'QuestionText': 'What discussions she has had with the Chancellor of the Exchequer on additional funding to increase the remuneration of people employed by fire and rescue services.',
#   'Status': 5,
#   'Number': 6,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901910,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4638,
#    'PimsId': 6209,
#    'Name': 'Mr Tanmanjeet Singh Dhesi',
#    'ListAs': 'Dhesi, Mr Tanmanjeet Singh',
#    'Constituency': 'Slough',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4638/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4638,
#   'AnsweringMinisterId': 0},
#  {'Id': 1237,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 6,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901900,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4517,
#    'PimsId': 6065,
#    'Name': 'Lucy Frazer',
#    'ListAs': 'Frazer, Lucy',
#    'Constituency': 'South East Cambridgeshire',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4517/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4517,
#   'AnsweringMinisterId': 0},
#  {'Id': 1213,
#   'QuestionType': 1,
#   'QuestionText': 'Whether her Department has commissioned research into alternatives to the use of immigration detention centres.',
#   'Status': 5,
#   'Number': 7,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901911,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 188,
#    'PimsId': 2851,
#    'Name': 'Sir Edward Davey',
#    'ListAs': 'Davey, Sir Edward',
#    'Constituency': 'Kingston and Surbiton',
#    'Status': 'Active',
#    'Party': 'Liberal Democrat',
#    'PartyId': 17,
#    'PartyColour': 'faa01a',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/188/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 188,
#   'AnsweringMinisterId': 0},
#  {'Id': 1238,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 7,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901901,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4640,
#    'PimsId': 6241,
#    'Name': 'David Linden',
#    'ListAs': 'Linden, David',
#    'Constituency': 'Glasgow East',
#    'Status': 'Active',
#    'Party': 'Scottish National Party',
#    'PartyId': 29,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4640/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4640,
#   'AnsweringMinisterId': 0},
#  {'Id': 1214,
#   'QuestionType': 1,
#   'QuestionText': 'What assessment she has made of the effectiveness of regional organised crime units.',
#   'Status': 5,
#   'Number': 8,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901912,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4517,
#    'PimsId': 6065,
#    'Name': 'Lucy Frazer',
#    'ListAs': 'Frazer, Lucy',
#    'Constituency': 'South East Cambridgeshire',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4517/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4517,
#   'AnsweringMinisterId': 0},
#  {'Id': 1239,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 8,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901902,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4369,
#    'PimsId': 6140,
#    'Name': 'Tom Pursglove',
#    'ListAs': 'Pursglove, Tom',
#    'Constituency': 'Corby',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4369/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4369,
#   'AnsweringMinisterId': 0},
#  {'Id': 1215,
#   'QuestionType': 1,
#   'QuestionText': 'If she will meet representatives from the Scottish fishing industry to discuss visas for crew members from outside the EEA.',
#   'Status': 5,
#   'Number': 9,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901913,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 1442,
#    'PimsId': 2481,
#    'Name': 'Mr Alistair Carmichael',
#    'ListAs': 'Carmichael, Mr Alistair',
#    'Constituency': 'Orkney and Shetland',
#    'Status': 'Active',
#    'Party': 'Liberal Democrat',
#    'PartyId': 17,
#    'PartyColour': 'faa01a',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1442/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 1442,
#   'AnsweringMinisterId': 0},
#  {'Id': 1240,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 9,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901903,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4267,
#    'PimsId': 6005,
#    'Name': 'Sarah Champion',
#    'ListAs': 'Champion, Sarah',
#    'Constituency': 'Rotherham',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4267/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4267,
#   'AnsweringMinisterId': 0},
#  {'Id': 1216,
#   'QuestionType': 1,
#   'QuestionText': 'What progress she has made on bringing perpetrators of major cyber crimes to justice.',
#   'Status': 5,
#   'Number': 10,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901914,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4669,
#    'PimsId': 6248,
#    'Name': 'Damien Moore',
#    'ListAs': 'Moore, Damien',
#    'Constituency': 'Southport',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4669/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4669,
#   'AnsweringMinisterId': 0},
#  {'Id': 1241,
#   'QuestionType': 2,
#   'QuestionText': 'If she will make a statement on her departmental responsibilities.',
#   'Status': 5,
#   'Number': 10,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901904,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 308,
#    'PimsId': 2803,
#    'Name': 'Mr Jim Cunningham',
#    'ListAs': 'Cunningham, Mr Jim',
#    'Constituency': 'Coventry South',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/308/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 308,
#   'AnsweringMinisterId': 0},
#  {'Id': 1217,
#   'QuestionType': 1,
#   'QuestionText': "Whether she plans to exclude international students from the Government's net migration target.",
#   'Status': 5,
#   'Number': 11,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901915,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 1604,
#    'PimsId': 5258,
#    'Name': 'Mr Virendra Sharma',
#    'ListAs': 'Sharma, Mr Virendra',
#    'Constituency': 'Ealing, Southall',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1604/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 1604,
#   'AnsweringMinisterId': 0},
#  {'Id': 1218,
#   'QuestionType': 1,
#   'QuestionText': 'What progress she has made on implementing the Dubs scheme.',
#   'Status': 5,
#   'Number': 12,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901916,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4634,
#    'PimsId': 6229,
#    'Name': 'Christine Jardine',
#    'ListAs': 'Jardine, Christine',
#    'Constituency': 'Edinburgh West',
#    'Status': 'Active',
#    'Party': 'Liberal Democrat',
#    'PartyId': 17,
#    'PartyColour': 'faa01a',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4634/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4634,
#   'AnsweringMinisterId': 0},
#  {'Id': 1219,
#   'QuestionType': 1,
#   'QuestionText': 'What recent steps she has taken to reduce the level of knife crime.',
#   'Status': 5,
#   'Number': 13,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901917,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 1585,
#    'PimsId': 4786,
#    'Name': 'Stephen Hammond',
#    'ListAs': 'Hammond, Stephen',
#    'Constituency': 'Wimbledon',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1585/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 1585,
#   'AnsweringMinisterId': 0},
#  {'Id': 1220,
#   'QuestionType': 1,
#   'QuestionText': 'Whether she plans to introduce a new police funding formula in the next 12 months.',
#   'Status': 5,
#   'Number': 14,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901918,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4136,
#    'PimsId': 5712,
#    'Name': 'Nigel Mills',
#    'ListAs': 'Mills, Nigel',
#    'Constituency': 'Amber Valley',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4136/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4136,
#   'AnsweringMinisterId': 0},
#  {'Id': 1221,
#   'QuestionType': 1,
#   'QuestionText': 'What representations she has received from higher education organisations on the Tier 4 visa pilot scheme for Masters students.',
#   'Status': 5,
#   'Number': 15,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901919,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4604,
#    'PimsId': 6233,
#    'Name': 'Stephen Kerr',
#    'ListAs': 'Kerr, Stephen',
#    'Constituency': 'Stirling',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4604/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4604,
#   'AnsweringMinisterId': 0},
#  {'Id': 1222,
#   'QuestionType': 1,
#   'QuestionText': 'What steps she is taking to identify, and prosecute people who return to the UK from fighting for Daesh in Syria.',
#   'Status': 11,
#   'Number': 16,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': '2017-11-20T16:23:30.48',
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901920,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4429,
#    'PimsId': 6058,
#    'Name': 'Mr William Wragg',
#    'ListAs': 'Wragg, Mr William',
#    'Constituency': 'Hazel Grove',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4429/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4429,
#   'AnsweringMinisterId': 0},
#  {'Id': 1223,
#   'QuestionType': 1,
#   'QuestionText': 'Whether her Department plans to review the effectiveness of its policy on indefinite detention. ',
#   'Status': 5,
#   'Number': 17,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901921,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4651,
#    'PimsId': 6204,
#    'Name': 'Dan Carden',
#    'ListAs': 'Carden, Dan',
#    'Constituency': 'Liverpool, Walton',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4651/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4651,
#   'AnsweringMinisterId': 0},
#  {'Id': 1224,
#   'QuestionType': 1,
#   'QuestionText': 'What discussions she has had with the Chancellor of the Exchequer on additional fundng to increase the remuneration of (a) police officers and (b) fire and rescue service workers; and if she will make a statement.',
#   'Status': 5,
#   'Number': 18,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901922,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4645,
#    'PimsId': 6223,
#    'Name': 'Emma Hardy',
#    'ListAs': 'Hardy, Emma',
#    'Constituency': 'Kingston upon Hull West and Hessle',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4645/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4645,
#   'AnsweringMinisterId': 0},
#  {'Id': 1225,
#   'QuestionType': 1,
#   'QuestionText': 'What steps she is taking to reduce dangerous journeys for unaccompanied child refugees with family in the UK.',
#   'Status': 5,
#   'Number': 19,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901923,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4469,
#    'PimsId': 6043,
#    'Name': 'Angela Crawley',
#    'ListAs': 'Crawley, Angela',
#    'Constituency': 'Lanark and Hamilton East',
#    'Status': 'Active',
#    'Party': 'Scottish National Party',
#    'PartyId': 29,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4469/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4469,
#   'AnsweringMinisterId': 0},
#  {'Id': 1226,
#   'QuestionType': 1,
#   'QuestionText': 'What discussions she has had with Cabinet colleagues on the effect of recent cyber-attacks on critical national infrastructure.',
#   'Status': 11,
#   'Number': 20,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': '2017-11-20T16:24:18.167',
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901924,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4501,
#    'PimsId': 6093,
#    'Name': 'Gerald Jones',
#    'ListAs': 'Jones, Gerald',
#    'Constituency': 'Merthyr Tydfil and Rhymney',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4501/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4501,
#   'AnsweringMinisterId': 0},
#  {'Id': 1227,
#   'QuestionType': 1,
#   'QuestionText': 'What steps she is taking to ensure that businesses have access to temporary non-UK EU workers after the UK leaves the EU.',
#   'Status': 11,
#   'Number': 21,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': '2017-11-20T16:24:42.857',
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901925,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4050,
#    'PimsId': 5579,
#    'Name': 'Gordon Henderson',
#    'ListAs': 'Henderson, Gordon',
#    'Constituency': 'Sittingbourne and Sheppey',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4050/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4050,
#   'AnsweringMinisterId': 0},
#  {'Id': 1228,
#   'QuestionType': 1,
#   'QuestionText': 'Whether her Department plans to review the effectiveness of the Prevent strategy.',
#   'Status': 11,
#   'Number': 22,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': '2017-11-20T16:24:57.787',
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901926,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4588,
#    'PimsId': 6190,
#    'Name': 'Tracy Brabin',
#    'ListAs': 'Brabin, Tracy',
#    'Constituency': 'Batley and Spen',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4588/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4588,
#   'AnsweringMinisterId': 0},
#  {'Id': 1229,
#   'QuestionType': 1,
#   'QuestionText': "Whether she plans to exclude international students from the Government's net migration target.",
#   'Status': 5,
#   'Number': 23,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901927,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4425,
#    'PimsId': 6163,
#    'Name': 'Jo Stevens',
#    'ListAs': 'Stevens, Jo',
#    'Constituency': 'Cardiff Central',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4425/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4425,
#   'AnsweringMinisterId': 0},
#  {'Id': 1230,
#   'QuestionType': 1,
#   'QuestionText': 'What progress the Government has made on placing vulnerable Syrian refugee families in the UK.',
#   'Status': 11,
#   'Number': 24,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': '2017-11-20T16:25:10.14',
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901928,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 4401,
#    'PimsId': 6139,
#    'Name': 'Victoria Prentis',
#    'ListAs': 'Prentis, Victoria',
#    'Constituency': 'Banbury',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4401/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4401,
#   'AnsweringMinisterId': 0},
#  {'Id': 1231,
#   'QuestionType': 1,
#   'QuestionText': "Whether she plans to exclude international students from the Government's net migration target",
#   'Status': 5,
#   'Number': 25,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901929,
#   'AnsweringWhen': '2017-11-20T00:00:00',
#   'AnsweringBodyId': 1,
#   'AnsweringBody': 'Home Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#   'AskingMember': {'MnisId': 308,
#    'PimsId': 2803,
#    'Name': 'Mr Jim Cunningham',
#    'ListAs': 'Cunningham, Mr Jim',
#    'Constituency': 'Coventry South',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/308/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 308,
#   'AnsweringMinisterId': 0},
#  {'Id': 1334,
#   'QuestionType': 1,
#   'QuestionText': 'When he last spoke with a representative of the Government of the Russian Federation.',
#   'Status': 5,
#   'Number': 1,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901940,
#   'AnsweringWhen': '2017-11-21T00:00:00',
#   'AnsweringBodyId': 16,
#   'AnsweringBody': 'Foreign and Commonwealth Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#   'AskingMember': {'MnisId': 1446,
#    'PimsId': 2350,
#    'Name': 'Chris Bryant',
#    'ListAs': 'Bryant, Chris',
#    'Constituency': 'Rhondda',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1446/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 1446,
#   'AnsweringMinisterId': 0},
#  {'Id': 1359,
#   'QuestionType': 2,
#   'QuestionText': 'If he will make a statement on his departmental responsibilities.',
#   'Status': 5,
#   'Number': 1,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901930,
#   'AnsweringWhen': '2017-11-21T00:00:00',
#   'AnsweringBodyId': 16,
#   'AnsweringBody': 'Foreign and Commonwealth Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#   'AskingMember': {'MnisId': 1533,
#    'PimsId': 4791,
#    'Name': 'Diana Johnson',
#    'ListAs': 'Johnson, Diana',
#    'Constituency': 'Kingston upon Hull North',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1533/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 1533,
#   'AnsweringMinisterId': 0},
#  {'Id': 1335,
#   'QuestionType': 1,
#   'QuestionText': 'What progress he has made on preparations for the Commonwealth Summit in London in April 2018.',
#   'Status': 5,
#   'Number': 2,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901941,
#   'AnsweringWhen': '2017-11-21T00:00:00',
#   'AnsweringBodyId': 16,
#   'AnsweringBody': 'Foreign and Commonwealth Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#   'AskingMember': {'MnisId': 4532,
#    'PimsId': 6167,
#    'Name': 'Derek Thomas',
#    'ListAs': 'Thomas, Derek',
#    'Constituency': 'St Ives',
#    'Status': 'Active',
#    'Party': 'Conservative',
#    'PartyId': 4,
#    'PartyColour': None,
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4532/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4532,
#   'AnsweringMinisterId': 0},
#  {'Id': 1360,
#   'QuestionType': 2,
#   'QuestionText': 'If he will make a statement on his departmental responsibilities.',
#   'Status': 5,
#   'Number': 2,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901931,
#   'AnsweringWhen': '2017-11-21T00:00:00',
#   'AnsweringBodyId': 16,
#   'AnsweringBody': 'Foreign and Commonwealth Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#   'AskingMember': {'MnisId': 4382,
#    'PimsId': 6025,
#    'Name': 'Daniel Zeichner',
#    'ListAs': 'Zeichner, Daniel',
#    'Constituency': 'Cambridge',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4382/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 4382,
#   'AnsweringMinisterId': 0},
#  {'Id': 1336,
#   'QuestionType': 1,
#   'QuestionText': 'What recent representations he has made to his counterpart in Myanmar on the treatment of the Rohingya people in that country.',
#   'Status': 5,
#   'Number': 3,
#   'TabledWhen': '2017-11-17T00:00:00',
#   'RemovedFromToBeAskedWhen': None,
#   'DeclarableInterestDetail': None,
#   'HansardLink': '',
#   'UIN': 901942,
#   'AnsweringWhen': '2017-11-21T00:00:00',
#   'AnsweringBodyId': 16,
#   'AnsweringBody': 'Foreign and Commonwealth Office',
#   'AnsweringMinisterTitle': 'the Secretary of State for Foreign and Commonwealth Affairs',
#   'AskingMember': {'MnisId': 1548,
#    'PimsId': 4824,
#    'Name': 'Jessica Morden',
#    'ListAs': 'Morden, Jessica',
#    'Constituency': 'Newport East',
#    'Status': 'Active',
#    'Party': 'Labour',
#    'PartyId': 15,
#    'PartyColour': 'd50000',
#    'PhotoUrl': 'https://members-api.parliament.uk/api/Members/1548/Portrait?cropType=OneOne&webVersion=true'},
#   'AnsweringMinister': None,
#   'AskingMemberId': 1548,
#   'AnsweringMinisterId': 0}]

# %%
# how many responses are there?
len(data['Response'])
# Out:
# 40

# %%
# we can access each response in the list (python uses 0-based indexing)
data['Response'][0]
# Out:
# {'Id': 1207,
#  'QuestionType': 1,
#  'QuestionText': 'What recent steps she has taken to reduce the level of knife crime.',
#  'Status': 5,
#  'Number': 1,
#  'TabledWhen': '2017-11-17T00:00:00',
#  'RemovedFromToBeAskedWhen': None,
#  'DeclarableInterestDetail': None,
#  'HansardLink': '',
#  'UIN': 901905,
#  'AnsweringWhen': '2017-11-20T00:00:00',
#  'AnsweringBodyId': 1,
#  'AnsweringBody': 'Home Office',
#  'AnsweringMinisterTitle': 'the Secretary of State for the Home Department',
#  'AskingMember': {'MnisId': 4498,
#   'PimsId': 6091,
#   'Name': 'Mr Ranil Jayawardena',
#   'ListAs': 'Jayawardena, Mr Ranil',
#   'Constituency': 'North East Hampshire',
#   'Status': 'Active',
#   'Party': 'Conservative',
#   'PartyId': 4,
#   'PartyColour': None,
#   'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4498/Portrait?cropType=OneOne&webVersion=true'},
#  'AnsweringMinister': None,
#  'AskingMemberId': 4498,
#  'AnsweringMinisterId': 0}

# %%
# let's write a function to convert the data into a pandas DataFrame
def pmqs_to_dataframe(data):
    # convert the list of responses to a DataFrame
    df = pd.DataFrame(data['Response'])
    
    return df

pmq_df = pmqs_to_dataframe(data)

# %%
pmq_df.head()
# Out:
#      Id  QuestionType                                       QuestionText  \
# 0  1207             1  What recent steps she has taken to reduce the ...
# 1  1232             2  If she will make a statement on her department...
# 2  1208             1  What steps she is taking to reduce dangerous j...
# 3  1233             2  If she will make a statement on her department...
# 4  1209             1  What steps she is taking to reduce dangerous j...
#
#    Status  Number           TabledWhen RemovedFromToBeAskedWhen  \
# 0       5       1  2017-11-17T00:00:00                     None
# 1       5       1  2017-11-17T00:00:00                     None
# 2       5       2  2017-11-17T00:00:00                     None
# 3       7       2  2017-11-17T00:00:00  2017-11-17T12:47:47.527
# 4       5       3  2017-11-17T00:00:00                     None
#
#   DeclarableInterestDetail HansardLink     UIN        AnsweringWhen  \
# 0                     None              901905  2017-11-20T00:00:00
# 1                     None              901895  2017-11-20T00:00:00
# 2                     None              901906  2017-11-20T00:00:00
# 3                     None              901896  2017-11-20T00:00:00
# 4                     None              901907  2017-11-20T00:00:00
#
#    AnsweringBodyId AnsweringBody  \
# 0                1   Home Office
# 1                1   Home Office
# 2                1   Home Office
# 3                1   Home Office
# 4                1   Home Office
#
#                            AnsweringMinisterTitle  \
# 0  the Secretary of State for the Home Department
# 1  the Secretary of State for the Home Department
# 2  the Secretary of State for the Home Department
# 3  the Secretary of State for the Home Department
# 4  the Secretary of State for the Home Department
#
#                                         AskingMember AnsweringMinister  \
# 0  {'MnisId': 4498, 'PimsId': 6091, 'Name': 'Mr R...              None
# 1  {'MnisId': 4664, 'PimsId': 6239, 'Name': 'Ms K...              None
# 2  {'MnisId': 4598, 'PimsId': 6219, 'Name': 'Moha...              None
# 3  {'MnisId': 4453, 'PimsId': 6152, 'Name': 'Tomm...              None
# 4  {'MnisId': 481, 'PimsId': 1031, 'Name': 'Mr Ge...              None
#
#    AskingMemberId  AnsweringMinisterId
# 0            4498                    0
# 1            4664                    0
# 2            4598                    0
# 3            4453                    0
# 4             481                    0

# %% [markdown]
# ## Step 2: Retrieve data on PMQs in 2025
#
# Remember, we want to create a `pandas` DataFrame with all the PMQs in 2025. We'll need to use pagination to retrieve all the data, as the API may not return all results in a single request.
#
# Oftentimes, good APIs will have features on the webpage that allow us to enter the parameters of our query, and then provide us with the URL that we can use to retrieve the data programmatically. We can use the API documentation to find out how to filter the data by date and other parameters. Doing so provides us with the following URL to retrieve PMQs for 2025:
#
# ```
# https://oralquestionsandmotions-api.parliament.uk/oralquestions/list?parameters.answeringDateStart=2025-01-01
# ```

# %%
pmq_endpoint_2025 = 'https://oralquestionsandmotions-api.parliament.uk/oralquestions/list?parameters.answeringDateStart=2025-01-01'

# %%
r = requests.get(pmq_endpoint_2025)
# check if the request was successful
print(f"Status code: {r.status_code}")
# Out:
# Status code: 200

# %%
data_2025 = r.json()
pmq_df_2025 = pmqs_to_dataframe(data_2025)
pmq_df_2025.head()
# Out:
#        Id  QuestionType                                       QuestionText  \
# 0  339423             2  If he will make a statement on his departmenta...
# 1  339662             1  What steps he is taking to increase military s...
# 2  339661             2  If he will make a statement on his departmenta...
# 3  340355             1  What steps he is taking to ensure that SMEs ar...
# 4  337796             2  If he will make a statement on his departmenta...
#
#    Status  Number           TabledWhen RemovedFromToBeAskedWhen  \
# 0       5       1  2024-12-19T00:00:00                     None
# 1       5       1  2024-12-19T00:00:00                     None
# 2       5       2  2024-12-19T00:00:00                     None
# 3       5       2  2024-12-19T00:00:00                     None
# 4       5       3  2024-12-19T00:00:00                     None
#
#   DeclarableInterestDetail HansardLink     UIN        AnsweringWhen  \
# 0                     None              901993  2025-01-06T00:00:00
# 1                     None              901968  2025-01-06T00:00:00
# 2                     None              901994  2025-01-06T00:00:00
# 3                     None              901969  2025-01-06T00:00:00
# 4                     None              901995  2025-01-06T00:00:00
#
#    AnsweringBodyId        AnsweringBody              AnsweringMinisterTitle  \
# 0               11  Ministry of Defence  the Secretary of State for Defence
# 1               11  Ministry of Defence  the Secretary of State for Defence
# 2               11  Ministry of Defence  the Secretary of State for Defence
# 3               11  Ministry of Defence  the Secretary of State for Defence
# 4               11  Ministry of Defence  the Secretary of State for Defence
#
#                                         AskingMember  \
# 0  {'MnisId': 5301, 'PimsId': 6717, 'Name': 'Rebe...
# 1  {'MnisId': 5289, 'PimsId': 6705, 'Name': 'Harp...
# 2  {'MnisId': 5289, 'PimsId': 6705, 'Name': 'Harp...
# 3  {'MnisId': 4813, 'PimsId': 6353, 'Name': 'Mr R...
# 4  {'MnisId': 5161, 'PimsId': 6577, 'Name': 'Rich...
#
#                                    AnsweringMinister  AskingMemberId  \
# 0  {'MnisId': 400, 'PimsId': 909, 'Name': 'John H...            5301
# 1  {'MnisId': 400, 'PimsId': 909, 'Name': 'John H...            5289
# 2  {'MnisId': 400, 'PimsId': 909, 'Name': 'John H...            5289
# 3  {'MnisId': 400, 'PimsId': 909, 'Name': 'John H...            4813
# 4  {'MnisId': 400, 'PimsId': 909, 'Name': 'John H...            5161
#
#    AnsweringMinisterId
# 0                  400
# 1                  400
# 2                  400
# 3                  400
# 4                  400

# %% [markdown]
# ### APIs will often only return a limited number of results per request, so we need to handle pagination. The API documentation should tell us how to do this, but often it involves using a `page` parameter in the URL. We therefore need to loop through the pages until we have retrieved all the data.

# %%
# Here, we see that a single call will return a maximum of 40 results. We want to 'skip' the next 40 results to access the next page of results. This requires us to use a new parameter called 'skip'
data_2025['PagingInfo']
# Out:
# {'Skip': 0,
#  'Take': 40,
#  'Total': 2506,
#  'GlobalTotal': 2506,
#  'StatusCounts': [],
#  'GlobalStatusCounts': []}

# %%
# we'll create a function to get the correct endpoint 

def get_pmq_endpoint(start_date, skip=0):
    """
    Function to get the PMQ endpoint for a given start date and skip value.
    
    Parameters:
    start_date (str): The start date in 'YYYY-MM-DD' format.
    skip (int): The number of results to skip.
    
    Returns:
    str: The PMQ endpoint URL.
    """
    return f'https://oralquestionsandmotions-api.parliament.uk/oralquestions/list?parameters.answeringDateStart={start_date}&parameters.skip={skip}'

# let's test the function
print(get_pmq_endpoint('2025-01-01', 0))  # First page
print(get_pmq_endpoint('2025-01-01', 40))  # Second page
# Out:
# https://oralquestionsandmotions-api.parliament.uk/oralquestions/list?parameters.answeringDateStart=2025-01-01&parameters.skip=0
# https://oralquestionsandmotions-api.parliament.uk/oralquestions/list?parameters.answeringDateStart=2025-01-01&parameters.skip=40

# %%
# now we'll create a function to loop through the pages to get all the results for a given start date

# it's 'polite' to not overload the server with requests, so we'll add a delay between requests
import time

def get_all_pmqs(start_date):
    """
    Function to get all PMQs from a given start date.
    
    Parameters:
    start_date (str): The start date in 'YYYY-MM-DD' format.
    
    Returns:
    pd.DataFrame: A DataFrame containing all PMQs.
    """
    all_pmqs = [] # initialize an empty list to store all PMQs
    skip = 0
    while True:
        endpoint = get_pmq_endpoint(start_date, skip)
        r = requests.get(endpoint)
        if r.status_code != 200:
            break
        data = r.json()
        if not data['Response']:
            break
        all_pmqs.extend(data['Response'])
        skip += 40  # Increment the skip value by 40 for the next page
        time.sleep(1) # to avoid overloading the server with requests
        print(f"Retrieved {len(data['Response'])} PMQs, total so far: {len(all_pmqs)}")
    return pd.DataFrame(all_pmqs)


# let's get all PMQs from 2025 ( I only used 2025-04-01 as an example, you can change it to any date you want)
pmqs_2025 = get_all_pmqs('2025-04-01')
# Out:
# Retrieved 40 PMQs, total so far: 40
# Retrieved 40 PMQs, total so far: 80
# Retrieved 40 PMQs, total so far: 120
# Retrieved 40 PMQs, total so far: 160
# Retrieved 40 PMQs, total so far: 200
# Retrieved 40 PMQs, total so far: 240
# Retrieved 40 PMQs, total so far: 280
# Retrieved 40 PMQs, total so far: 320
# Retrieved 40 PMQs, total so far: 360
# Retrieved 40 PMQs, total so far: 400
# Retrieved 40 PMQs, total so far: 440
# Retrieved 40 PMQs, total so far: 480
# Retrieved 40 PMQs, total so far: 520
# Retrieved 40 PMQs, total so far: 560
# Retrieved 40 PMQs, total so far: 600
# Retrieved 40 PMQs, total so far: 640
# Retrieved 40 PMQs, total so far: 680
# Retrieved 40 PMQs, total so far: 720
# Retrieved 40 PMQs, total so far: 760
# Retrieved 40 PMQs, total so far: 800
# Retrieved 40 PMQs, total so far: 840
# Retrieved 40 PMQs, total so far: 880
# Retrieved 40 PMQs, total so far: 920
# Retrieved 15 PMQs, total so far: 935

# %%
# display the dataframe 
pmqs_2025
# Out:
#          Id  QuestionType                                       QuestionText  \
# 0    359524             2  If he will make a statement on his departmenta...
# 1    359585             1  What diplomatic steps he is taking to increase...
# 2    358715             2  If he will make a statement on his departmenta...
# 3    359538             1  What assessment he has made of the potential i...
# 4    358019             1  Which development programmes he plans to maint...
# ..      ...           ...                                                ...
# 930  367819             1  What recent progress he has made on establishi...
# 931  367484             1  What steps his Department is taking to reform ...
# 932  366391             1  What steps he has taken to encourage the insou...
# 933  368011             1  What steps he is taking to improve relations w...
# 934  368780             1  How frequently he plans to publish the List of...
#
#      Status  Number           TabledWhen RemovedFromToBeAskedWhen  \
# 0         5       1  2025-03-26T00:00:00                     None
# 1         7       1  2025-03-26T00:00:00   2025-03-27T07:28:42.14
# 2         5       2  2025-03-26T00:00:00                     None
# 3         5       2  2025-03-26T00:00:00                     None
# 4         8       3  2025-03-26T00:00:00   2025-03-27T08:01:00.67
# ..      ...     ...                  ...                      ...
# 930       5      20  2025-05-22T00:00:00                     None
# 931       7      21  2025-05-22T00:00:00   2025-05-27T17:14:55.07
# 932       5      22  2025-05-22T00:00:00                     None
# 933       5      23  2025-05-22T00:00:00                     None
# 934       5      24  2025-05-22T00:00:00                     None
#
#     DeclarableInterestDetail HansardLink     UIN        AnsweringWhen  \
# 0                       None              903557  2025-04-01T00:00:00
# 1                       None              903532  2025-04-01T00:00:00
# 2                       None              903558  2025-04-01T00:00:00
# 3                       None              903533  2025-04-01T00:00:00
# 4                       None              903534  2025-04-01T00:00:00
# ..                       ...         ...     ...                  ...
# 930                     None              904377  2025-06-05T00:00:00
# 931                     None              904378  2025-06-05T00:00:00
# 932                     None              904379  2025-06-05T00:00:00
# 933                     None              904380  2025-06-05T00:00:00
# 934                     None              904381  2025-06-05T00:00:00
#
#      AnsweringBodyId                                 AnsweringBody  \
# 0                208  Foreign, Commonwealth and Development Office
# 1                208  Foreign, Commonwealth and Development Office
# 2                208  Foreign, Commonwealth and Development Office
# 3                208  Foreign, Commonwealth and Development Office
# 4                208  Foreign, Commonwealth and Development Office
# ..               ...                                           ...
# 930               53                                Cabinet Office
# 931               53                                Cabinet Office
# 932               53                                Cabinet Office
# 933               53                                Cabinet Office
# 934               53                                Cabinet Office
#
#                                 AnsweringMinisterTitle  \
# 0    the Secretary of State for Foreign, Commonweal...
# 1    the Secretary of State for Foreign, Commonweal...
# 2    the Secretary of State for Foreign, Commonweal...
# 3    the Secretary of State for Foreign, Commonweal...
# 4    the Secretary of State for Foreign, Commonweal...
# ..                                                 ...
# 930                the Minister for the Cabinet Office
# 931                the Minister for the Cabinet Office
# 932                the Minister for the Cabinet Office
# 933                the Minister for the Cabinet Office
# 934                the Minister for the Cabinet Office
#
#                                           AskingMember AnsweringMinister  \
# 0    {'MnisId': 4776, 'PimsId': 6418, 'Name': 'Muni...              None
# 1    {'MnisId': 4124, 'PimsId': 5617, 'Name': 'Chi ...              None
# 2    {'MnisId': 345, 'PimsId': 1455, 'Name': 'Sir E...              None
# 3    {'MnisId': 415, 'PimsId': 3727, 'Name': 'Fabia...              None
# 4    {'MnisId': 5358, 'PimsId': 6774, 'Name': 'John...              None
# ..                                                 ...               ...
# 930  {'MnisId': 4515, 'PimsId': 6132, 'Name': 'Kate...              None
# 931  {'MnisId': 5081, 'PimsId': 6497, 'Name': 'Joe ...              None
# 932  {'MnisId': 5232, 'PimsId': 6648, 'Name': 'Lorr...              None
# 933  {'MnisId': 5247, 'PimsId': 6663, 'Name': 'Soja...              None
# 934  {'MnisId': 5304, 'PimsId': 6720, 'Name': 'Dr D...              None
#
#      AskingMemberId  AnsweringMinisterId
# 0              4776                    0
# 1              4124                    0
# 2               345                    0
# 3               415                    0
# 4              5358                    0
# ..              ...                  ...
# 930            4515                    0
# 931            5081                    0
# 932            5232                    0
# 933            5247                    0
# 934            5304                    0
#
# [935 rows x 18 columns]

# %%
# let's look at the columns in the DataFrame
pmqs_2025.columns
# Out:
# Index(['Id', 'QuestionType', 'QuestionText', 'Status', 'Number', 'TabledWhen',
#        'RemovedFromToBeAskedWhen', 'DeclarableInterestDetail', 'HansardLink',
#        'UIN', 'AnsweringWhen', 'AnsweringBodyId', 'AnsweringBody',
#        'AnsweringMinisterTitle', 'AskingMember', 'AnsweringMinister',
#        'AskingMemberId', 'AnsweringMinisterId'],
#       dtype='object')

# %% [markdown]
# ## Columns for the DataFrame
#
# Remember, we want to create a `pandas` DataFrame with the following columns:
#
# - `Date`: Date the question was asked
# - `MP`: Name of the Member of Parliament (MP) who asked the question
# - `Id`: Unique identifier for the question
# - `QuestionText`: Text of the question
# - `AnsweringBody`: The body that answered the question
# - `AnsweringMinisterTitle`: Title of the minister who answered the question
#
# Additionally, we can include any columns that are relevant to our analysis, such as the type of question or the topic.
#
# One thing worth noting is that many APIs will return nested json objects. For example, the `AskingMember` field in the PMQs API returns an object with the MP's name, ID, constituency and other variables. We will need to extract the relevant information from these nested objects to create our DataFrame. See below for an example:

# %%
pmqs_2025.AskingMember[0]
# Out:
# {'MnisId': 4776,
#  'PimsId': 6418,
#  'Name': 'Munira Wilson',
#  'ListAs': 'Wilson, Munira',
#  'Constituency': 'Twickenham',
#  'Status': 'Active',
#  'Party': 'Liberal Democrat',
#  'PartyId': 17,
#  'PartyColour': 'faa01a',
#  'PhotoUrl': 'https://members-api.parliament.uk/api/Members/4776/Portrait?cropType=OneOne&webVersion=true'}

# %%
# convert the 'AskingMember' column to a DataFrame
def extract_member_info(df):
    """
    Function to extract member information from the 'AskingMember' column.
    
    Parameters:
    df (pd.DataFrame): The DataFrame containing PMQs.
    
    Returns:
    pd.DataFrame: A DataFrame containing member information.
    """
    members_df = pd.json_normalize(df['AskingMember'])
    return members_df

# extract member information
members_df = extract_member_info(pmqs_2025)
# display the first few rows of the members DataFrame
members_df.head()
# Out:
#    MnisId  PimsId              Name             ListAs  \
# 0    4776    6418     Munira Wilson     Wilson, Munira
# 1    4124    5617       Chi Onwurah       Onwurah, Chi
# 2     345    1455  Sir Edward Leigh  Leigh, Sir Edward
# 3     415    3727   Fabian Hamilton   Hamilton, Fabian
# 4    5358    6774       John Cooper       Cooper, John
#
#                            Constituency  Status             Party  PartyId  \
# 0                            Twickenham  Active  Liberal Democrat       17
# 1  Newcastle upon Tyne Central and West  Active            Labour       15
# 2                          Gainsborough  Active      Conservative        4
# 3                      Leeds North East  Active            Labour       15
# 4                 Dumfries and Galloway  Active      Conservative        4
#
#   PartyColour                                           PhotoUrl
# 0      faa01a  https://members-api.parliament.uk/api/Members/...
# 1      d50000  https://members-api.parliament.uk/api/Members/...
# 2      0063ba  https://members-api.parliament.uk/api/Members/...
# 3      d50000  https://members-api.parliament.uk/api/Members/...
# 4      0063ba  https://members-api.parliament.uk/api/Members/...

# %%
# because the 'AskingMember' column is a list of dictionaries, we can use the 'json_normalize' function to flatten it into a DataFrame 

# the extracted DataFrame is the same length as the original DataFrame, so we can concatenate it with the original DataFrame
pmqs_2025 = pd.concat([pmqs_2025, members_df], axis=1)
# display the first few rows of the updated DataFrame
pmqs_2025.head()
# Out:
#        Id  QuestionType                                       QuestionText  \
# 0  359524             2  If he will make a statement on his departmenta...
# 1  359585             1  What diplomatic steps he is taking to increase...
# 2  358715             2  If he will make a statement on his departmenta...
# 3  359538             1  What assessment he has made of the potential i...
# 4  358019             1  Which development programmes he plans to maint...
#
#   Status  Number           TabledWhen RemovedFromToBeAskedWhen  \
# 0      5       1  2025-03-26T00:00:00                     None
# 1      7       1  2025-03-26T00:00:00   2025-03-27T07:28:42.14
# 2      5       2  2025-03-26T00:00:00                     None
# 3      5       2  2025-03-26T00:00:00                     None
# 4      8       3  2025-03-26T00:00:00   2025-03-27T08:01:00.67
#
#   DeclarableInterestDetail HansardLink     UIN  ... MnisId  PimsId  \
# 0                     None              903557  ...   4776    6418
# 1                     None              903532  ...   4124    5617
# 2                     None              903558  ...    345    1455
# 3                     None              903533  ...    415    3727
# 4                     None              903534  ...   5358    6774
#
#                Name             ListAs                          Constituency  \
# 0     Munira Wilson     Wilson, Munira                            Twickenham
# 1       Chi Onwurah       Onwurah, Chi  Newcastle upon Tyne Central and West
# 2  Sir Edward Leigh  Leigh, Sir Edward                          Gainsborough
# 3   Fabian Hamilton   Hamilton, Fabian                      Leeds North East
# 4       John Cooper       Cooper, John                 Dumfries and Galloway
#
#    Status             Party  PartyId  PartyColour  \
# 0  Active  Liberal Democrat       17       faa01a
# 1  Active            Labour       15       d50000
# 2  Active      Conservative        4       0063ba
# 3  Active            Labour       15       d50000
# 4  Active      Conservative        4       0063ba
#
#                                             PhotoUrl
# 0  https://members-api.parliament.uk/api/Members/...
# 1  https://members-api.parliament.uk/api/Members/...
# 2  https://members-api.parliament.uk/api/Members/...
# 3  https://members-api.parliament.uk/api/Members/...
# 4  https://members-api.parliament.uk/api/Members/...
#
# [5 rows x 28 columns]

# %%
# at this point, we could save the DataFrame to a CSV file or perform further analysis
# let's save the DataFrame to a CSV file
# create a directory to save the file
import os
if not os.path.exists('data'):
    os.makedirs('data')
# save the DataFrame to a CSV file
pmqs_2025.to_csv('data/pmqs_2025.csv', index=False)
# display a message to indicate that the file has been saved
print("PMQs data for 2025 has been saved to 'data/pmqs_2025.csv'.")
# Out:
# PMQs data for 2025 has been saved to 'data/pmqs_2025.csv'.
